# %% [markdown]
# # Task # 4 - To Explore Decision Tree Algorithm
# Mallika Shrivastava

# %%
import sklearn.datasets as datasets
import pandas as pd
iris=datasets.load_iris()
df=pd.DataFrame(iris.data, columns=iris.feature_names)
y=iris.target

# %%
df.shape
# Out:
# (150, 4)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Plot all the variables

df['petal width (cm)'].plot.hist()
plt.show()
df['petal length (cm)'].plot.hist()
plt.show()
df['sepal width (cm)'].plot.hist()
plt.show()
df['sepal length (cm)'].plot.hist()
plt.show()

# %%
# Plot the relationship between the vavriable
sns.pairplot(df)

# %% [markdown]
# # Defining Decision Tree Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(df,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# # Visualising the decision tree

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=(25,15))
fn=['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']
tree.plot_tree(dtree,feature_names=fn,filled=True)
# Out:
# [Text(697.5, 747.4499999999999, 'petal length (cm) <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(590.1923076923077, 611.55, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(804.8076923076923, 611.55, 'petal width (cm) <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(429.2307692307692, 475.65, 'petal length (cm) <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(214.6153846153846, 339.74999999999994, 'petal width (cm) <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(107.3076923076923, 203.8499999999999, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(321.9230769230769, 203.8499999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(643.8461538461538, 339.74999999999994, 'petal width (cm) <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(536.5384615384615, 203.8499999999999, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(751.1538461538462, 203.8499999999999, 'sepal length (cm) <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(643.8461538461538, 67.94999999999993, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(858.4615384615385, 67.94999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(1180.3846153846155, 475.65, 'petal length (cm) <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(1073.076923076923, 339.74999999999994, 'sepal width (cm) <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(965.7692307692307, 203.8499999999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(1180.3846153846155, 203.8499999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(1287.6923076923076, 339.74999999999994, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]
